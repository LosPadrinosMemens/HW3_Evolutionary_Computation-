# %%
from GA import *
from Problems import *
from utils import *
from PSO import *
import matplotlib.pyplot as plt
import pickle
import time

import random
import numpy as np
np.random.seed(42)
random.seed(42)

# %%
g_test_problems = ["G1", "G4", "G5", "G6"]
g_results = {problem: {"DE+SR": [], "GA": []} for problem in g_test_problems}
g_unweighted_penalty = {problem: {"DE+SR": [], "GA": []} for problem in g_test_problems}
g_num_violations = {problem: {"DE+SR": [], "GA": []} for problem in g_test_problems} 

for test_problem in g_test_problems:
    g_n = test_problem[-1]
    print('\n +---------------------------------------+')

    for i in range(50):
        start_time = time.time()
        a = Population(test_problem, config_file=f"inputs/params_g{g_n}.cfg", penalty=False)
        a.evolve("DE+SR")
        b = functions.dict_to_dataframe(a.generation_statistics)
        g_results[test_problem]["DE+SR"].append(b["best_fitness"].iloc[-1])
        g_unweighted_penalty[test_problem]["DE+SR"].append(b["unweighted_penalty"].iloc[-1])
        g_num_violations[test_problem]["DE+SR"].append(b["num_violations"].iloc[-1])
        elapsed_time = time.time() - start_time
        print(f'{test_problem} \t DE+SR \t Iter {i} \t {elapsed_time:2.2f}s', end = '\r')
    print('\n')

    for i in range(50):
        start_time = time.time()
        a = Population(test_problem, config_file=f"inputs/params_g{g_n}.cfg", penalty=True)
        a.evolve("GA")
        b = functions.dict_to_dataframe(a.generation_statistics)
        g_results[test_problem]["GA"].append(b["best_fitness"].iloc[-1])
        g_unweighted_penalty[test_problem]["GA"].append(b["unweighted_penalty"].iloc[-1])
        g_num_violations[test_problem]["GA"].append(b["num_violations"].iloc[-1])
        elapsed_time = time.time() - start_time
        print(f'{test_problem} \t GA \t Iter {i} \t {elapsed_time:2.2f}s', end = '\r') 
    print('\n')

with open('g_results_seq.pkl', 'rb') as file:
    pickle.dump([g_results,g_unweighted_penalty, g_num_violations], file)
# Out:
#  +---------------------------------------+
# G1 	 DE+SR 	 Iter 49 	 1.77s
#
# G1 	 GA 	 Iter 49 	 2.01s
#
#
#  +---------------------------------------+
# G4 	 DE+SR 	 Iter 49 	 1.45s
#
# G4 	 GA 	 Iter 37 	 1.77s

# %%
functions.compare_algorithms(g_results, 0.05)

# %% [markdown]
# ## Parallel

# %%
import time
from concurrent.futures import ProcessPoolExecutor, as_completed

g_test_problems = ["G1", "G4", "G5", "G6"] 
g_results = {problem: {"DE+SR": [], "GA": []} for problem in g_test_problems}
g_unweighted_penalty = {problem: {"DE+SR": [], "GA": []} for problem in g_test_problems}
g_num_violations = {problem: {"DE+SR": [], "GA": []} for problem in g_test_problems}

def run_experiment(test_problem, i, method, penalty):
    g_n = test_problem[-1]
    a = Population(test_problem, config_file=f"inputs/params_g{g_n}.cfg", penalty=penalty)
    a.evolve(method)
    b = functions.dict_to_dataframe(a.generation_statistics)
    result = {
        "best_fitness": b["best_fitness"].iloc[-1],
        "unweighted_penalty": b["unweighted_penalty"].iloc[-1],
        "num_violations": b["num_violations"].iloc[-1],
    }
    return test_problem, method, result

with ProcessPoolExecutor() as executor:
    futures = []
    for test_problem in g_test_problems:
        for i in range(50):
            start_time = time.time()
            futures.append(executor.submit(run_experiment, test_problem, i, "DE+SR", False))
            elapsed_time = time.time() - start_time
            print(f'{test_problem} \t DE+SR \t Iter {i} \t {elapsed_time:2.2f}s')
        
        for i in range(50):
            start_time = time.time()
            futures.append(executor.submit(run_experiment, test_problem, i, "GA", True))
# G6 	 "GA" 	 Iter 35 	 0.00s
# G6 	 "GA" 	 Iter 36 	 0.00s
# G6 	 "GA" 	 Iter 37 	 0.00s
# G6 	 "GA" 	 Iter 38 	 0.00s
# G6 	 "GA" 	 Iter 39 	 0.00s
# G6 	 "GA" 	 Iter 40 	 0.00s
# G6 	 "GA" 	 Iter 41 	 0.00s
# G6 	 "GA" 	 Iter 42 	 0.00s
# G6 	 "GA" 	 Iter 43 	 0.00s
# G6 	 "GA" 	 Iter 44 	 0.00s
# G6 	 "GA" 	 Iter 45 	 0.00s
# G6 	 "GA" 	 Iter 46 	 0.00s
# G6 	 "GA" 	 Iter 47 	 0.00s
# G6 	 "GA" 	 Iter 48 	 0.00s
# G6 	 "GA" 	 Iter 49 	 0.00s

# %%
with open('results_1_parallel.pkl', 'wb') as file:
    pickle.dump([g_results,g_unweighted_penalty, g_num_violations], file)

# %% [markdown]
# ## Layeb

# %%
import warnings

warnings.filterwarnings("ignore", category=RuntimeWarning)

l_test_problems = ["Layeb05", "Layeb10", "Layeb15", "Layeb18"]
l_results = {problem: {"PSO": [], "GA": [], "DE": []} for problem in l_test_problems}
l_unweighted_penalty = {problem: {"PSO": [], "GA": [], "DE": []} for problem in l_test_problems}
l_num_violations = {problem: {"PSO": [], "GA": [], "DE": []} for problem in l_test_problems} 

for test_problem in l_test_problems:
    print('\n +---------------------------------------+')

    for i in range(30):
        try:
            a = PSO(test_problem, n_var = 2, config_file = "inputs/param_swarm.cfg")
            a.run()
            b = functions.dict_to_dataframe(a.generation_statistics)
            l_results[test_problem]["PSO"].append(b["best_fitness"].iloc[-1])
            print(f'{test_problem} \t PSO \t Iter {i:2d}', end = '\r')    
        except Exception as e:
            print(f'{test_problem} \t PSO \t Iter {i:2d} FAILED due to {e}')    
            l_results[test_problem]["GA"].append(-1e100)

    print('\n')
    
    for i in range(30):
        try:
            a = Population(test_problem, n_var = 2, config_file=f"inputs/params_layeb.cfg", penalty=False)
            a.evolve("GA")
            b = functions.dict_to_dataframe(a.generation_statistics)
            l_results[test_problem]["GA"].append(b["best_fitness"].iloc[-1])
            print(f'{test_problem} \t GA \t Iter {i:2d}', end = '\r')
        except Exception as e:
            print(f'{test_problem} \t GA \t Iter {i:2d} FAILED due to {e}')
            l_results[test_problem]["GA"].append(-1e100)

    print('\n')
    
    for i in range(30):
        try:
            a = Population(test_problem, n_var = 2, config_file=f"inputs/params_layeb.cfg", penalty=False)
            a.evolve("DE")
            b = functions.dict_to_dataframe(a.generation_statistics)

            l_results[test_problem]["DE"].append(b["best_fitness"].iloc[-1])
            print(f'{test_problem} \t DE \t Iter {i:2d}', end = '\r')         
        except Exception as e:
            print(f'{test_problem} \t DE \t Iter {i:2d} FAILED due to {e}')
            l_results[test_problem]["GA"].append(-1e100)

    print('\n')

with open('l_results_sequential.pkl', 'wb') as file:
    pickle.dump(l_results, file)(file)
# Out:
#  +---------------------------------------+
# Layeb05 	 PSO 	 Iter 29
#
# Layeb05 	 GA 	 Iter 29
#
# Layeb05 	 DE 	 Iter 29
#
#
#  +---------------------------------------+
# Layeb10 	 PSO 	 Iter 29
#
# Layeb10 	 GA 	 Iter 29
#
# Layeb10 	 DE 	 Iter 29
#
#
#  +---------------------------------------+
# Layeb15 	 PSO 	 Iter 29
#
# Layeb15 	 GA 	 Iter  0 FAILED due to probabilities contain NaN
# Layeb15 	 GA 	 Iter  1 FAILED due to probabilities contain NaN
# Layeb15 	 GA 	 Iter  2 FAILED due to probabilities contain NaN
# Layeb15 	 GA 	 Iter  3 FAILED due to probabilities contain NaN
# Layeb15 	 GA 	 Iter  4 FAILED due to probabilities contain NaN
# Layeb15 	 GA 	 Iter  5 FAILED due to probabilities contain NaN
# Layeb15 	 GA 	 Iter  6 FAILED due to probabilities contain NaN
# Layeb15 	 GA 	 Iter  7 FAILED due to probabilities contain NaN
# Layeb15 	 GA 	 Iter  8 FAILED due to probabilities contain NaN
# Layeb15 	 GA 	 Iter  9 FAILED due to probabilities contain NaN
# Layeb15 	 GA 	 Iter 10 FAILED due to probabilities contain NaN
# Layeb15 	 GA 	 Iter 11 FAILED due to probabilities contain NaN
# Layeb15 	 GA 	 Iter 12 FAILED due to probabilities contain NaN
# Layeb15 	 GA 	 Iter 13 FAILED due to probabilities contain NaN
# Layeb15 	 GA 	 Iter 14 FAILED due to probabilities contain NaN
# Layeb15 	 GA 	 Iter 15 FAILED due to probabilities contain NaN
# Layeb15 	 GA 	 Iter 16 FAILED due to probabilities contain NaN
# Layeb15 	 GA 	 Iter 17 FAILED due to probabilities contain NaN
# Layeb15 	 GA 	 Iter 18 FAILED due to probabilities contain NaN
# Layeb15 	 GA 	 Iter 19 FAILED due to probabilities contain NaN
# Layeb15 	 GA 	 Iter 20 FAILED due to probabilities contain NaN
# Layeb15 	 GA 	 Iter 21 FAILED due to probabilities contain NaN
# Layeb15 	 GA 	 Iter 22 FAILED due to probabilities contain NaN
# Layeb15 	 GA 	 Iter 23 FAILED due to probabilities contain NaN
# Layeb15 	 GA 	 Iter 24 FAILED due to probabilities contain NaN
# Layeb15 	 GA 	 Iter 25 FAILED due to probabilities contain NaN
# Layeb15 	 GA 	 Iter 26 FAILED due to probabilities contain NaN
# Layeb15 	 GA 	 Iter 27 FAILED due to probabilities contain NaN
# Layeb15 	 GA 	 Iter 28 FAILED due to probabilities contain NaN
# Layeb15 	 GA 	 Iter 29 FAILED due to probabilities contain NaN
#
#
# Layeb15 	 DE 	 Iter 29
#
#
#  +---------------------------------------+
# Layeb18 	 PSO 	 Iter 29
#
# Layeb18 	 GA 	 Iter  0 FAILED due to 'p' must be 1-dimensional
# Layeb18 	 GA 	 Iter  1 FAILED due to 'p' must be 1-dimensional
# Layeb18 	 GA 	 Iter  2 FAILED due to 'p' must be 1-dimensional
# Layeb18 	 GA 	 Iter  3 FAILED due to 'p' must be 1-dimensional
# Layeb18 	 GA 	 Iter  4 FAILED due to 'p' must be 1-dimensional
# Layeb18 	 GA 	 Iter  5 FAILED due to 'p' must be 1-dimensional
# Layeb18 	 GA 	 Iter  6 FAILED due to 'p' must be 1-dimensional
# Layeb18 	 GA 	 Iter  7 FAILED due to 'p' must be 1-dimensional
# Layeb18 	 GA 	 Iter  8 FAILED due to 'p' must be 1-dimensional
# Layeb18 	 GA 	 Iter  9 FAILED due to 'p' must be 1-dimensional
# Layeb18 	 GA 	 Iter 10 FAILED due to 'p' must be 1-dimensional
# Layeb18 	 GA 	 Iter 11 FAILED due to 'p' must be 1-dimensional
# Layeb18 	 GA 	 Iter 12 FAILED due to 'p' must be 1-dimensional
# Layeb18 	 GA 	 Iter 13 FAILED due to 'p' must be 1-dimensional
# Layeb18 	 GA 	 Iter 14 FAILED due to 'p' must be 1-dimensional
# Layeb18 	 GA 	 Iter 15 FAILED due to 'p' must be 1-dimensional
# Layeb18 	 GA 	 Iter 16 FAILED due to 'p' must be 1-dimensional
# Layeb18 	 GA 	 Iter 17 FAILED due to 'p' must be 1-dimensional
# Layeb18 	 GA 	 Iter 18 FAILED due to 'p' must be 1-dimensional
# Layeb18 	 GA 	 Iter 19 FAILED due to 'p' must be 1-dimensional
# Layeb18 	 GA 	 Iter 20 FAILED due to 'p' must be 1-dimensional
# Layeb18 	 GA 	 Iter 21 FAILED due to 'p' must be 1-dimensional
# Layeb18 	 GA 	 Iter 22 FAILED due to 'p' must be 1-dimensional
# Layeb18 	 GA 	 Iter 23 FAILED due to 'p' must be 1-dimensional
# Layeb18 	 GA 	 Iter 24 FAILED due to 'p' must be 1-dimensional
# Layeb18 	 GA 	 Iter 25 FAILED due to 'p' must be 1-dimensional
# Layeb18 	 GA 	 Iter 26 FAILED due to 'p' must be 1-dimensional
# Layeb18 	 GA 	 Iter 27 FAILED due to 'p' must be 1-dimensional
# Layeb18 	 GA 	 Iter 28 FAILED due to 'p' must be 1-dimensional
# Layeb18 	 GA 	 Iter 29 FAILED due to 'p' must be 1-dimensional
#
#
# Layeb18 	 DE 	 Iter  0 FAILED due to 'numpy.ndarray' object has no attribute 'fitness'
# Layeb18 	 DE 	 Iter  1 FAILED due to 'numpy.ndarray' object has no attribute 'fitness'
# Layeb18 	 DE 	 Iter  2 FAILED due to 'numpy.ndarray' object has no attribute 'fitness'
# Layeb18 	 DE 	 Iter  3 FAILED due to 'numpy.ndarray' object has no attribute 'fitness'
# Layeb18 	 DE 	 Iter  4 FAILED due to 'numpy.ndarray' object has no attribute 'fitness'
# Layeb18 	 DE 	 Iter  5 FAILED due to 'numpy.ndarray' object has no attribute 'fitness'
# Layeb18 	 DE 	 Iter  6 FAILED due to 'numpy.ndarray' object has no attribute 'fitness'
# Layeb18 	 DE 	 Iter  7 FAILED due to 'numpy.ndarray' object has no attribute 'fitness'
# Layeb18 	 DE 	 Iter  8 FAILED due to 'numpy.ndarray' object has no attribute 'fitness'
# Layeb18 	 DE 	 Iter  9 FAILED due to 'numpy.ndarray' object has no attribute 'fitness'
# Layeb18 	 DE 	 Iter 10 FAILED due to 'numpy.ndarray' object has no attribute 'fitness'
# Layeb18 	 DE 	 Iter 11 FAILED due to 'numpy.ndarray' object has no attribute 'fitness'
# Layeb18 	 DE 	 Iter 12 FAILED due to 'numpy.ndarray' object has no attribute 'fitness'
# Layeb18 	 DE 	 Iter 13 FAILED due to 'numpy.ndarray' object has no attribute 'fitness'
# Layeb18 	 DE 	 Iter 14 FAILED due to 'numpy.ndarray' object has no attribute 'fitness'
# Layeb18 	 DE 	 Iter 15 FAILED due to 'numpy.ndarray' object has no attribute 'fitness'
# Layeb18 	 DE 	 Iter 16 FAILED due to 'numpy.ndarray' object has no attribute 'fitness'
# Layeb18 	 DE 	 Iter 17 FAILED due to 'numpy.ndarray' object has no attribute 'fitness'
# Layeb18 	 DE 	 Iter 18 FAILED due to 'numpy.ndarray' object has no attribute 'fitness'
# Layeb18 	 DE 	 Iter 19 FAILED due to 'numpy.ndarray' object has no attribute 'fitness'
# Layeb18 	 DE 	 Iter 20 FAILED due to 'numpy.ndarray' object has no attribute 'fitness'
# Layeb18 	 DE 	 Iter 21 FAILED due to 'numpy.ndarray' object has no attribute 'fitness'
# Layeb18 	 DE 	 Iter 22 FAILED due to 'numpy.ndarray' object has no attribute 'fitness'
# Layeb18 	 DE 	 Iter 23 FAILED due to 'numpy.ndarray' object has no attribute 'fitness'
# Layeb18 	 DE 	 Iter 24 FAILED due to 'numpy.ndarray' object has no attribute 'fitness'
# Layeb18 	 DE 	 Iter 25 FAILED due to 'numpy.ndarray' object has no attribute 'fitness'
# Layeb18 	 DE 	 Iter 26 FAILED due to 'numpy.ndarray' object has no attribute 'fitness'
# Layeb18 	 DE 	 Iter 27 FAILED due to 'numpy.ndarray' object has no attribute 'fitness'
# Layeb18 	 DE 	 Iter 28 FAILED due to 'numpy.ndarray' object has no attribute 'fitness'
# Layeb18 	 DE 	 Iter 29 FAILED due to 'numpy.ndarray' object has no attribute 'fitness'

# %%
def replace_nan_in_dict(d):
    for key, value in d.items():
        if isinstance(value, dict):
            replace_nan_in_dict(value)
        elif isinstance(value, list):
            new_list = []
            for item in value:
                if isinstance(item, (float, np.float64, np.float32, np.float16)):
                    if np.isnan(item):
                        new_list.append(np.float64(-1e200))
                    else:
                        new_list.append(item)
                elif isinstance(item, np.ndarray):
                    if np.isnan(item).any():
                        new_list.append(np.full_like(item, -1e200, dtype=np.float64))
                    else:
                        new_list.append(item)
                else:
                    new_list.append(item)
            d[key] = new_list
        else:
            pass

replace_nan_in_dict(l_results)

# %%
l_results
# Out:
# {'Layeb05': {'PSO': [np.float64(-6.90760706209424),
#    np.float64(-6.907729328670729),
#    np.float64(-6.907625525620355),
#    np.float64(-6.906653742833855),
#    np.float64(-6.907741703770475),
#    np.float64(-6.907735609316635),
#    np.float64(-6.9076596969356086),
#    np.float64(-6.907732574139597),
#    np.float64(-6.907750876656352),
#    np.float64(-6.907748708769624),
#    np.float64(-6.907716452894551),
#    np.float64(-6.9077213323605005),
#    np.float64(-6.907518837922187),
#    np.float64(-6.907719744998799),
#    np.float64(-6.9077509328229425),
#    np.float64(-6.907619313310158),
#    np.float64(-6.90770760093134),
#    np.float64(-6.907736804872657),
#    np.float64(-6.907703759416843),
#    np.float64(-6.90771949453402),
#    np.float64(-6.907754189615884),
#    np.float64(-6.907729009611577),
#    np.float64(-6.907682030128473),
#    np.float64(-6.907728129239369),
#    np.float64(-6.907582018549112),
#    np.float64(-6.907752822015355),
#    np.float64(-6.907746662117968),
#    np.float64(-6.907755147828836),
e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100],
#   'DE': [np.float64(-1e+200),
#    np.float64(-1e+200),
#    np.float64(10.999999916500046),
#    np.float64(-1e+200),
#    np.float64(-1e+200),
#    np.float64(-1e+200),
#    np.float64(-1e+200),
#    np.float64(-1e+200),
#    np.float64(-1e+200),
#    np.float64(-1e+200),
#    np.float64(-1e+200),
#    np.float64(-1e+200),
#    np.float64(10.999770060753008),
#    np.float64(-1e+200),
#    np.float64(-1e+200),
#    np.float64(-1e+200),
#    np.float64(-1e+200),
#    np.float64(-1e+200),
#    np.float64(-1e+200),
#    np.float64(-1e+200),
#    np.float64(-1e+200),
#    np.float64(-1e+200),
#    np.float64(-1e+200),
#    np.float64(-1e+200),
#    np.float64(-1e+200),
#    np.float64(-1e+200),
#    np.float64(-1e+200),
#    np.float64(-1e+200),
#    np.float64(-1e+200),
#    np.float64(-1e+200)]},
#  'Layeb18': {'PSO': [array([-7.37805417]),
#    array([-8.01832151]),
#    array([-10.8242724]),
#    array([-11.08648827]),
#    array([-8.34735616]),
#    array([-8.8515214]),
#    array([-8.8995001]),
#    array([-11.83007782]),
#    array([-11.57073223]),
#    array([-7.40168271]),
#    array([-13.78977484]),
#    array([-7.44950905]),
#    array([-12.18420025]),
#    array([-7.00374242]),
#    array([-9.77512432]),
#    array([-10.30913302]),
#    array([-10.44949024]),
#    array([-8.52009825]),
#    array([-11.79000498]),
#    array([-6.68423187]),
#    array([-13.51443376]),
#    array([-11.24612633]),
#    array([-10.52509002]),
#    array([-9.58457953]),
#    array([-9.52605806]),
#    array([-9.35713361]),
#    array([-7.97339332]),
#    array([-9.72419605]),
#    array([-8.29748269]),
#    array([-10.40600759])],
#   'GA': [-1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100],
#   'DE': []}}

# %%
functions.compare_algorithms(l_results, 0.05)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 functions.compare_algorithms(l_results, 0.05)
#
# File /mnt/d/sharegit/EvoComp/HW3_Evolutionary_Computation-/utils/functions.py:141, in compare_algorithms(results, p_value_threshold)
#     139 stat, p_value = ranksums(performanceA, performanceB)
#     140 conclusion = "No significant difference"
# --> 141 if p_value < p_value_threshold:
#     142     conclusion = f"{algA} outperforms {algB}" if stat < 0 else f"{algB} outperforms {algA}"
#     144 comparison_results[problem][f"{algA} vs {algB}"] = {
#     145     "statistic": stat,
#     146     "p_value": p_value,
#     147     "conclusion": conclusion
#     148 }
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
l_results

# %%
l_results
# Out:
# {'Layeb05': {'PSO': [np.float64(-6.907740059986439),
#    np.float64(-6.907734879808116),
#    np.float64(-6.907735892975993),
#    np.float64(-6.907739748345752),
#    np.float64(-6.907750662984612),
#    np.float64(-6.9077280937658605),
#    np.float64(-6.90764173376245),
#    np.float64(-6.907741076262719),
#    np.float64(-6.907737516951073),
#    np.float64(-6.907753480703013),
#    np.float64(-6.9077463906456416),
#    np.float64(-6.907598894727074),
#    np.float64(-6.9073976353223765),
#    np.float64(-6.907488172436543),
#    np.float64(-6.907747581961238),
#    np.float64(-6.907569082657055),
#    np.float64(-6.907751771448358),
#    np.float64(-6.907619158423586),
#    np.float64(-6.907753961995051),
#    np.float64(-6.907720561907776),
#    np.float64(-6.907644383786099),
#    np.float64(-6.907692147734842),
#    np.float64(-6.9027023199324855),
#    np.float64(-6.90767055218899),
#    np.float64(-6.907753854127577),
#    np.float64(-6.907671317288276),
#    np.float64(-6.907755177105722),
#    np.float64(-6.907707882675586),
#    np.float64(-6.907168438776859),
#    np.float64(-6.9077418296147375)],
#   'GA': [np.float64(-6.841658037703457),
#    np.float64(-6.808101828349182),
#    np.float64(-6.786164034685377),
#    np.float64(-6.736422570016717),
#    np.float64(-6.757718506315367),
#    np.float64(-6.672192134681763),
#    np.float64(-6.888948205034572),

#    np.float64(nan),
#    np.float64(nan),
#    np.float64(nan),
#    np.float64(nan),
#    np.float64(nan),
#    np.float64(nan),
#    np.float64(nan),
#    np.float64(nan),
#    np.float64(nan),
#    np.float64(11.0),
#    np.float64(nan),
#    np.float64(nan),
#    np.float64(nan)]},
#  'Layeb18': {'PSO': [array([-7.93256935]),
#    array([-10.21856246]),
#    array([-9.60029015]),
#    array([-8.35706873]),
#    array([-8.02038204]),
#    array([-12.46115678]),
#    array([-11.23088598]),
#    array([-9.50752526]),
#    array([-9.99348794]),
#    array([-11.53178189]),
#    array([-9.87734759]),
#    array([-12.20123762]),
#    array([-8.52693096]),
#    array([-10.66535224]),
#    array([-9.31151037]),
#    array([-9.18212263]),
#    array([-8.17241852]),
#    array([-8.94767507]),
#    array([-10.39364013]),
#    array([-8.98416542]),
#    array([-8.87693139]),
#    array([-10.25075254]),
#    array([-9.76801343]),
#    array([-8.32835607]),
#    array([-7.79428267]),
#    array([-9.14844808]),
#    array([-9.26820583]),
#    array([-8.81624402]),
#    array([-8.41193313]),
#    array([-9.12185741])],
#   'GA': [-1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100],
#   'DE': [-1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100,
#    -1e+100]}}

# %%
with open('l_results_sequential.pkl', 'wb') as file:
    pickle.dump(l_results, file)(file)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 with open('l_results_sequential.pkl', 'wb') as file:
# ----> 2     pickle.dump(l_results, file)(file)
#       3 functions.compare_algorithms(l_results, 0.05)
#       4 g_results
#
# TypeError: 'NoneType' object is not callable

# %%
functions.compare_algorithms(g_results, 0.05)
# Out:
# {'G1': {'DE': [9, 9, 9, 9, 9], 'GA': [9, 9, 9, 9, 9]},
#  'G4': {'DE': [6, 6, 6, 6, 6], 'GA': [6, 6, 6, 6, 6]},
#  'G5': {'DE': [6, 6, 6, 6, 6], 'GA': [6, 6, 6, 6, 6]},
#  'G6': {'DE': [1, 1, 1, 2, 1], 'GA': [2, 1, 1, 1, 2]}}

# %%
a.evolve("DE")

# %%
a.evolve("GA")

# %%
a.best_chromosome.calculate_fitness()

# %%
b = functions.dict_to_dataframe(a.generation_statistics)

# %%
b["best_fitness"].iloc[-1]
# Out:
# 57.503794558394375

# %%
a.evolve()
# Out:
# 4

# %%
for i in range(a.pop_size):
    print(a.chromosomes[i].genes)
# Out:
# [90.33401053 64.61322927]
# [17.69069256 64.82750429]
# [17.71205209 36.99073275]
# [35.43228435 11.15560026]

# %%
for i in range(a.pop_size):
    print(a.chromosomes[i].fitness)
# Out:
# 612526.8955206232
# 92352.57606645417
# 5902.534311824702
# 16168.46046834587

# %%
for i in range(a.pop_size):
    a.chromosomes[i].calculate_fitness()
    print(a.chromosomes[i].fitness)
# Out:
# 620993.4174686676
# 95259.13011571343
# 6764.749628837317
# 16825.533089372275

# %%
a.generation_t
# Out:
# 3

# %%
a.get_population_statistics()
# Out:
# (6549.195799584164, 184154.93482968872, 253285.0168583821)

# %%
a.binomial_crossover_and_selection()

# %%
a.tournament_selection(q=1)

# %%
a.sbx_and_pbm()

# %%
for c in b:
    print(c.fitness)
# Out:
# 15.804508093893453
# 3.454327341743649
# 2.586957486130423
# 3.454327341743649
# 3.454327341743649

# %%
print(a.fitness)
# Out:
# 0.6714053969469278

# %%
a.parameter_based_mutation()

# %%
a.genes
# Out:
# array([ 0.35317455, -0.73937347])

# %%
a.polynomial_mutation()
